# %%
import numpy as np
tc= np.array([[20,85.6,30.2]])
tk = tc * 9/5 + 32
print(tk)
print(tk.ndim)
print(tk.shape)
print(tk.size)
print(tk.dtype)
print(tc.ndim)
# Out:
# [[ 68.   186.08  86.36]]
# 2
# (1, 3)
# 3
# float64
# 2
